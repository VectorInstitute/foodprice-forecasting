# %%
import pandas as pd
pd.set_option('precision', 3)

experiment_names = ["nbeatsfredvars_202110", "nbeats_202110", "prophet_202110", "ensemble_202110", "neuralprophet_202110_DEXCAUS_nlags_24"]

mape_results = []

for ex in experiment_names:
    metrics = pd.read_csv(f"./output/{ex}/mean_fc_valid_metrics.csv", index_col=0)
    metrics = metrics['mape'].rename(f"{ex}_mape")
    mape_results.append(metrics)

results_df = pd.concat(mape_results, axis=1)
results_df
# Out:
#                                                   nbeatsfredvars_202110_mape  \
# Bakery and cereal products (excluding baby food)                       0.020
# Dairy products and eggs                                                0.018
# Fish, seafood and other marine products                                0.015
# Food purchased from restaurants                                        0.007
# Food                                                                   0.012
# Fruit, fruit preparations and nuts                                     0.032
# Meat                                                                   0.024
# Other food products and non-alcoholic beverages                        0.012
# Vegetables and vegetable preparations                                  0.049
#
#                                                   nbeats_202110_mape  \
# Bakery and cereal products (excluding baby food)               0.037
# Dairy products and eggs                                        0.042
# Fish, seafood and other marine products                        0.042
# Food purchased from restaurants                                0.032
# Food                                                           0.030
# Fruit, fruit preparations and nuts                             0.051
# Meat                                                           0.037
# Other food products and non-alcoholic beverages                0.028
# Vegetables and vegetable preparations                          0.056
#
#                                                   prophet_202110_mape  \
# Bakery and cereal products (excluding baby food)                0.027
# Dairy products and eggs                                         0.030
# Fish, seafood and other marine products                         0.019
# Food purchased from restaurants                                 0.012
# Food                                                            0.014
# Fruit, fruit preparations and nuts                              0.035
# Meat                                                            0.036
# Other food products and non-alcoholic beverages                 0.012
# Vegetables and vegetable preparations                           0.046
#
#                                                   ensemble_202110_mape  \
# Bakery and cereal products (excluding baby food)                 0.007
# Dairy products and eggs                                          0.031
# Fish, seafood and other marine products                          0.022
# Food purchased from restaurants                                  0.008
# Food                                                             0.006
# Fruit, fruit preparations and nuts                               0.012
# Meat                                                             0.017
# Other food products and non-alcoholic beverages                  0.013
# Vegetables and vegetable preparations                            0.032
#
#                                                   neuralprophet_202110_DEXCAUS_nlags_24_mape
# Bakery and cereal products (excluding baby food)                                       0.029
# Dairy products and eggs                                                                0.027
# Fish, seafood and other marine products                                                0.034
# Food purchased from restaurants                                                        0.028
# Food                                                                                   0.027
# Fruit, fruit preparations and nuts                                                     0.037
# Meat                                                                                   0.028
# Other food products and non-alcoholic beverages                                        0.030
# Vegetables and vegetable preparations                                                  0.041

# %%
results_df.T[['Meat']] * 100
# Out:
#                             Meat
# nbeatsfredvars_202110_mape  2.37
# nbeats_202110_mape          3.65
# prophet_202110_mape         3.63
# ensemble_202110_mape        1.71
